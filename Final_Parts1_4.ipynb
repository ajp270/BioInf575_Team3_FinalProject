# %% [markdown]
# 1. Map/merge the 23andme file and the variant-drug annotation file based on dbSNP_ID (also known as rsID).
# The merged result should have the following columns:
#
# dbSNP_ID, GENE_SYMBOL, DRUG_NAME, PMID, PHENOTYPE_CATEGORY, SIGNIFICANCE, NOTES, SENTENCE, ALLELE_PharmGKB (variant alleles in annotation), ALLELE_23andme (variant alleles in 23andme file)

# %%
import pandas as pd

_23andme_v5 = pd.read_csv("23andme_v5_hg19_ref.txt", sep="\t", header = None, names = ["CHR", "POS", "dbSNP_ID", "ALLELE_23andme"])

var_drug_ann = pd.read_csv("var_drug_ann.tsv", sep="\t")

#renaming to match the assignment naming conventions
var_drug_ann.rename(columns={
    "Variant/Haplotypes": "dbSNP_ID",
    "Gene": "GENE_SYMBOL",
    "Drug(s)": "DRUG_NAME",
    "Phenotype Category": "PHENOTYPE_CATEGORY",
    "Significance": "SIGNIFICANCE",
    "Notes": "NOTES",
    "Sentence": "SENTENCE",
    "Alleles": "ALLELE_PharmGKB"
}, inplace=True)

#just keeping the columns we need
var_drug_ann = var_drug_ann[[
    "dbSNP_ID",
    "GENE_SYMBOL",
    "DRUG_NAME",
    "PMID",
    "PHENOTYPE_CATEGORY",
    "SIGNIFICANCE",
    "NOTES",
    "SENTENCE",
    "ALLELE_PharmGKB"
]]

merged = pd.merge(var_drug_ann, _23andme_v5[["dbSNP_ID", "ALLELE_23andme"]], on="dbSNP_ID", how="inner")
merged.head()
# Out:
#      dbSNP_ID GENE_SYMBOL                                          DRUG_NAME  \
# 0    rs706795       FAIM2  citalopram, escitalopram, fluoxetine, fluvoxam...
# 1  rs16918842       OPRK1                                             heroin
# 2    rs163184       KCNQ1                                        sitagliptin
# 3   rs7754840      CDKAL1                                        sitagliptin
# 4   rs1799853      CYP2C9                                        sitagliptin
#
#        PMID PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0  40054571           Efficacy           no
# 1  31940240             Dosage           no
# 2  39792745           Efficacy          yes
# 3  39792745           Efficacy           no
# 4  39792745           Efficacy          yes
#
#                                                NOTES  \
# 0  "We observed nominally significant association...
# 1  No significant difference in allele or genotyp...
# 2  "KCNQ1 gene polymorphisms also significantly a...
# 3  "Patients with the rs7754840 CG genotype showe...
# 4  "CYP2C9 gene polymorphisms also significantly ...
#
#                                             SENTENCE ALLELE_PharmGKB  \
# 0  Allele T is associated with increased response...               T
# 1  Allele T is not associated with dose of heroin...               T
# 2  Genotype GG is associated with decreased respo...              GG
# 3  Genotype CG is associated with increased respo...              CG
# 4  Genotype TT is associated with decreased respo...              TT
#
#   ALLELE_23andme
# 0              T
# 1              C
# 2              T
# 3              G
# 4              C

# %% [markdown]
# 2. Filter the output so that it only contains significant associations (SIGNIFICANCE is yes) for variants that affect the drug efficacy (PHENOTYPE_CATEGORY is efficacy).

# %%
filtered = merged[
    (merged["SIGNIFICANCE"].str.lower() == "yes") &
    (merged["PHENOTYPE_CATEGORY"].str.lower() == "efficacy")
].reset_index(drop=True)
filtered.head()
# Out:
#     dbSNP_ID GENE_SYMBOL                                          DRUG_NAME  \
# 0   rs163184       KCNQ1                                        sitagliptin
# 1  rs1799853      CYP2C9                                        sitagliptin
# 2  rs7903146      TCF7L2                                          exenatide
# 3  rs8099917       IFNL3  peginterferon alfa-2a, peginterferon alfa-2b, ...
# 4  rs8099917       IFNL3                   peginterferon alfa-2b, ribavirin
#
#        PMID PHENOTYPE_CATEGORY SIGNIFICANCE  \
# 0  39792745           Efficacy          yes
# 1  39792745           Efficacy          yes
# 2  30700996           Efficacy          yes
# 3  26075078           Efficacy          yes
# 4  22328925           Efficacy          yes
#
#                                                NOTES  \
# 0  "KCNQ1 gene polymorphisms also significantly a...
# 1  "CYP2C9 gene polymorphisms also significantly ...
# 2  "After treatment with exenatide, only CT/TT in...
# 3  A multivariate logistic model showed that the ...
# 4  This genotype is associated with sustained vir...
#
#                                             SENTENCE ALLELE_PharmGKB  \
# 0  Genotype GG is associated with decreased respo...              GG
# 1  Genotype TT is associated with decreased respo...              TT
# 2  Genotypes CT + TT is associated with increased...         CT + TT
# 3  Genotype TT is associated with increased respo...              TT
# 4  Genotype TT is associated with increased respo...              TT
#
#   ALLELE_23andme
# 0              T
# 1              C
# 2              C
# 3              T
# 4              T

# %% [markdown]
# 3) Save the output of the filtering step in a tab-separated file (23andme_PharmGKB_map.tsv) with the following columns:
#
# dbSNP_ID, GENE_SYMBOL, DRUG_NAME, NOTES, SENTENCE, ALLELE_PharmGKB, ALLELE_23andme

# %%
### Removing Columns that aren't required in tsv ###
columns_to_drop = ['PMID', 'PHENOTYPE_CATEGORY', 'SIGNIFICANCE']
filtered_for_export = filtered.drop(columns=columns_to_drop)
# Out:
#         dbSNP_ID GENE_SYMBOL  \
# 0       rs163184       KCNQ1
# 1      rs1799853      CYP2C9
# 2      rs7903146      TCF7L2
# 3      rs8099917       IFNL3
# 4      rs8099917       IFNL3
# ...          ...         ...
# 1430   rs7756992      CDKAL1
# 1431  rs11549465       HIF1A
# 1432   rs1042713       ADRB2
# 1433  rs11572080      CYP2C8
# 1434      rs6265        BDNF
#
#                                               DRUG_NAME  \
# 0                                           sitagliptin
# 1                                           sitagliptin
# 2                                             exenatide
# 3     peginterferon alfa-2a, peginterferon alfa-2b, ...
# 4                      peginterferon alfa-2b, ribavirin
# ...                                                 ...
# 1430          Dipeptidyl peptidase 4 (DPP-4) inhibitors
# 1431                 cisplatin, gemcitabine, pemetrexed
# 1432                                        mepolizumab
# 1433                       corticosteroids, montelukast
# 1434                                      empagliflozin
#
#                                                   NOTES  \
# 0     "KCNQ1 gene polymorphisms also significantly a...
# 1     "CYP2C9 gene polymorphisms also significantly ...
# 2     "After treatment with exenatide, only CT/TT in...
# 3     A multivariate logistic model showed that the ...
# 4     This genotype is associated with sustained vir...
# ...                                                 ...
# 1430  The SNP was significantly associated with impr...
# 1431  "In heterozygotes with the HIF1A rs11549465 CT...
# 1432  "Our findings also suggest that this polymorph...
# 1433  Alleles complemented."Mean asthma control scor...
# 1434  "BDNF rs6265 showed a strong association with ...
#
#                                                SENTENCE ALLELE_PharmGKB  \
# 0     Genotype GG is associated with decreased respo...              GG
# 1     Genotype TT is associated with decreased respo...              TT
# 2     Genotypes CT + TT is associated with increased...         CT + TT
# 3     Genotype TT is associated with increased respo...              TT
# 4     Genotype TT is associated with increased respo...              TT
# ...                                                 ...             ...
# 1430  Genotype GG is associated with increased respo...              GG
# 1431  Genotype CT is associated with decreased respo...              CT
# 1432  Allele G is associated with increased clinical...               G
# 1433  Genotype CC is associated with increased clini...              CC
# 1434  Genotype CC is associated with increased clini...              CC
#
#      ALLELE_23andme
# 0                 T
# 1                 C
# 2                 C
# 3                 T
# 4                 T
# ...             ...
# 1430              A
# 1431              C
# 1432              G
# 1433              C
# 1434              C
#
# [1435 rows x 7 columns]

# %%
### write tsv ###
filtered_for_export.to_csv('23andme_PharmGKB_map.tsv', sep='\t', index=False)

# %% [markdown]
# 4) Create a tab separated file (23andme_PharmGKB_summary.tsv) with summarized data with the following columns:
#
# GENE_SYMBOL, DRUG_NAME, dbSNP_IDs (list of IDs separated by ";")

# %%
### Remove Columns that aren't required in tsv ###
summary = filtered[['GENE_SYMBOL', 'DRUG_NAME', 'dbSNP_ID']]

### Summarise dbSNP_ID info###
summarised = (
    summary.groupby(['GENE_SYMBOL', 'DRUG_NAME'], as_index=False)
    .agg(dbSNP_IDs=("dbSNP_ID",lambda x: ";".join(x))))
summarised
# Out:
#     GENE_SYMBOL                                          DRUG_NAME  \
# 0         ABCA1            atorvastatin, rosuvastatin, simvastatin
# 1         ABCA1                                        fenofibrate
# 2         ABCB1                                    antidepressants
# 3         ABCB1                                     antipsychotics
# 4         ABCB1                                      carbamazepine
# ..          ...                                                ...
# 900       XRCC3                   cisplatin, docetaxel, irinotecan
# 901       XRCC4     fluorouracil, Platinum compounds, radiotherapy
# 902      ZNF432  budesonide, corticosteroids, fluticasone / sal...
# 903      ZNF697             interferon beta-1a, interferon beta-1b
# 904     ZNF804A                                     antipsychotics
#
#                          dbSNP_IDs
# 0                        rs2230806
# 1    rs2230806;rs2230808;rs2230806
# 2                        rs1128503
# 3                        rs1128503
# 4                        rs1128503
# ..                             ...
# 900                       rs861539
# 901                      rs2075685
# 902                      rs3752120
# 903                     rs10494227
# 904                      rs1344706
#
# [905 rows x 3 columns]

# %%
### write tsv ###
summarised.to_csv('23andme_PharmGKB_summary.tsv', sep="\t", index=False)
